# %%
import numpy as np
import pandas as pd
import seaborn as sea 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Balancete Anual

# %%
bca = pd.read_csv('/home/joao/Projetos/trabalho_fasam/data_viz/data/geral/bca.csv')


bca = bca.rename(index = str, columns={"Year": "Ano", "Value":"Valor (Bilhões de Reais)"})

bca['Ano'] = bca['Ano'].apply(lambda x: x[0:4])

# %%
def periods(row):
    if row['Ano'] < '2003':
        return 'FHC'
    if row['Ano'] >= '2003' and row['Ano'] < '2011':
        return 'Lula'
    if row['Ano'] >= '2011':
        return "Dilma"

# %%
bca['Periodos'] = bca.apply(lambda row: periods(row), axis = 1)

# %%
bca = bca.apply(pd.to_numeric, errors = 'ignore')

bca
# Out:
#      Ano  Valor (Bilhões de Reais) Periodos
# 0   1995                   -18.384      FHC
# 1   1996                   -23.502      FHC
# 2   1997                   -30.453      FHC
# 3   1998                   -33.416      FHC
# 4   1999                   -25.334      FHC
# 5   2000                   -24.224      FHC
# 6   2001                   -23.215      FHC
# 7   2002                    -7.637      FHC
# 8   2003                     4.178     Lula
# 9   2004                    11.679     Lula
# 10  2005                    13.985     Lula
# 11  2006                    13.642     Lula
# 12  2007                     1.551     Lula
# 13  2008                   -28.192     Lula
# 14  2009                   -24.302     Lula
# 15  2010                   -47.273     Lula
# 16  2011                   -52.473    Dilma
# 17  2012                   -54.249    Dilma
# 18  2013                   -81.227    Dilma
# 19  2014                   -91.289    Dilma
# 20  2015                   -69.737    Dilma
# 21  2016                   -66.296    Dilma

# %%
tips = sea.load_dataset('tips')

# %%
plt.close()
sea.set_style("whitegrid", {'axes.grid' : False})
clrs = ['red' if (ano >= 2003) else 'blue' for ano in bca['Ano']]
fig, ax = plt.subplots()
ax.set_title('Balancete Anual')
sea.set_context("talk")

fig.set_size_inches(25.7, 8.27)
plt.axvline(x=1995, color='B', label='Início Governo FHC (1995)')
plt.axvline(x=2003, color=sea.xkcd_rgb["dusty purple"], label='Início Governo Lula (2003)')
plt.axvline(x=2011, color= sea.xkcd_rgb["pale red"], label = 'Início Governo Dilma (2011)')
sea.lineplot(x='Ano', y ='Valor (Bilhões de Reais)', palette = clrs, data = bca)


sea.despine()

# %% [markdown]
# ## Gastos x Receita

# %%
total = pd.read_csv('/home/joao/Projetos/trabalho_fasam/data_viz/data/geral/ggr_ggx_ggxwdg.csv')


total = total.rename(index = str, columns={"Year": "Ano", "Value":"Valor (Bilhões de Reais)"})

total['Ano'] = total['Ano'].apply(lambda x: x[0:4])

total['Periodos'] = total.apply(lambda row: periods(row), axis = 1)

total
# Out:
#      Ano   Receita    Gastos    Divida Periodos
# 0   2000   373.664   413.470   786.135      FHC
# 1   2001   435.015   476.748   921.736      FHC
# 2   2002   513.615   579.415  1173.131      FHC
# 3   2003   615.364   704.306  1268.243     Lula
# 4   2004   692.324   748.630  1371.930     Lula
# 5   2005   786.874   863.682  1488.699     Lula
# 6   2006   858.668   944.677  1586.507     Lula
# 7   2007   949.199  1023.659  1733.983     Lula
# 8   2008  1115.843  1163.527  1923.972     Lula
# 9   2009  1130.527  1236.769  2164.607     Lula
# 10  2010  1401.939  1507.592  2449.830     Lula
# 11  2011  1536.455  1644.418  2678.502    Dilma
# 12  2012  1669.011  1790.326  2994.571    Dilma
# 13  2013  1835.345  1992.888  3209.247    Dilma
# 14  2014  1877.095  2221.011  3600.867    Dilma
# 15  2015  2052.063  2366.974  3941.618    Dilma
# 16  2016  2189.901  2490.602  4207.750    Dilma

# %%
total = total.apply(pd.to_numeric, errors = 'ignore')

# %%
plt.close()
#ggr = sea.load_dataset('oi')
fig, ax = plt.subplots()
fig.set_size_inches(25.7, 8.27)

sea.set_context("talk")


sea.set_color_codes("muted")
sea.barplot(x="Ano", y="Gastos", data=total,
            label="Gastos", color="r")

sea.set_color_codes("pastel")
sea.barplot(x="Ano", y="Receita", data=total,
            label="Receita", color="g")


ax.legend(ncol=2, loc="upper left", frameon=True)
ax.set(ylabel="Valor (Bilhões de Reais)",
       xlabel="Ano")
sea.despine(left=True, bottom=True)
sea.set_style("whitegrid")

# %% [markdown]
# ## Dívida Bruta

# %%
plt.close()
#ggr = sea.load_dataset('oi')
fig, ax = plt.subplots()
ax.set_title('Dívida Bruta')
fig.set_size_inches(25.7, 8.27)

sea.set_context("talk")

sea.set_color_codes("pastel")
sea.barplot(x="Ano", y="Divida", data=total,
            color=sea.xkcd_rgb["dusty purple"])



ax.set(ylabel="Dívida (Bilhões de Reais)",
       xlabel="Ano")
sea.despine(left=True, bottom=True)
sea.set_style("whitegrid")

# %% [markdown]
# ## Taxa de Desemprego

# %%
lur = pd.read_csv('/home/joao/Projetos/trabalho_fasam/data_viz/data/geral/lur.csv')



lur = lur.rename(index = str, columns={"Year": "Ano", "Value":"Porcentagem da Força de Trabalho"})

lur['Ano'] = lur['Ano'].apply(lambda x: x[0:4])

lur = lur.apply(pd.to_numeric, errors = 'ignore')

lur
# Out:
#      Ano  Porcentagem da Força de Trabalho
# 0   1995                             4.650
# 1   1996                             5.433
# 2   1997                             5.684
# 3   1998                             7.597
# 4   1999                             7.600
# 5   2000                             7.100
# 6   2001                            11.265
# 7   2002                            11.683
# 8   2003                            12.317
# 9   2004                            11.483
# 10  2005                             9.833
# 11  2006                             9.983
# 12  2007                             9.275
# 13  2008                             7.892
# 14  2009                             8.075
# 15  2010                             6.750
# 16  2011                             5.967
# 17  2012                             5.483
# 18  2013                             5.392
# 19  2014                             4.842
# 20  2015                             5.912
# 21  2016                             6.289

# %%
plt.close()
fig2, ax2 = plt.subplots()
ax2.set_title('Taxa de Desemprego')
sea.set_context("talk")
fig2.set_size_inches(25.7, 8.27)
plt.axvline(x=1995, color='B', label='Início Governo FHC (1995)')
plt.axvline(x=2003, color=sea.xkcd_rgb["dusty purple"], label='Início Governo Lula (2003)')
plt.axvline(x=2011, color= sea.xkcd_rgb["pale red"], label = 'Início Governo Dilma (2011)')
sea.lineplot(x='Ano', y ='Porcentagem da Força de Trabalho', palette = clrs, data = lur)
sea.despine()
sea.set_style("whitegrid", {'axes.grid' : False})

# %% [markdown]
# ## PIB - NGDP

# %%
pib = pd.read_csv('/home/joao/Projetos/trabalho_fasam/data_viz/data/geral/ngdp.csv')



pib = pib.rename(index = str, columns={"Year": "Ano", "PIB":"Valor(Bilhões de Reais)"})

pib['Ano'] = pib['Ano'].apply(lambda x: x[0:4])

pib = pib.apply(pd.to_numeric, errors = 'ignore')

pib
# Out:
#      Ano  Valor(Bilhões de Reais)
# 0   1995                  720.985
# 1   1996                  857.857
# 2   1997                  955.464
# 3   1998                 1005.985
# 4   1999                 1092.277
# 5   2000                 1202.377
# 6   2001                 1316.319
# 7   2002                 1491.183
# 8   2003                 1720.069
# 9   2004                 1958.705
# 10  2005                 2171.736
# 11  2006                 2409.802
# 12  2007                 2718.031
# 13  2008                 3107.530
# 14  2009                 3328.174
# 15  2010                 3886.835
# 16  2011                 4374.765
# 17  2012                 4713.095
# 18  2013                 5157.569
# 19  2014                 5521.256
# 20  2015                 5954.605
# 21  2016                 6358.276

# %%
plt.close()
fig2, ax2 = plt.subplots()
ax2.set_title('Produto Interno Bruto')
sea.set_context("talk")
fig2.set_size_inches(25.7, 8.27)
plt.axvline(x=1995, color='B', label='Início Governo FHC (1995)')
plt.axvline(x=2003, color=sea.xkcd_rgb["dusty purple"], label='Início Governo Lula (2003)')
plt.axvline(x=2011, color= sea.xkcd_rgb["pale red"], label = 'Início Governo Dilma (2011)')
sea.lineplot(x='Ano', y ='Valor(Bilhões de Reais)', markers=True, data = pib)
sea.despine()
sea.set_style("whitegrid", {'axes.grid' : False})

# %%
def calcula_total(ano_inicial, ano_final):
    inicial = pib[pib['Ano'] == ano_inicial]['Valor(Bilhões de Reais)'].values
    final= pib[pib['Ano'] == ano_final]['Valor(Bilhões de Reais)'].values
    oi = final - inicial
    return oi

# %%
fhc = calcula_total(1995, 2003)

lula = calcula_total(2003, 2011)

dilma = calcula_total(2011,2016)

# %%
pib_total = pd.DataFrame({'Valor':[fhc[0],lula[0],dilma[0]], 'Presidente':['FHC', 'Lula', 'Dilma']})

# %%
pib_total
# Out:
#   Presidente     Valor
# 0        FHC   999.084
# 1       Lula  2654.696
# 2      Dilma  1983.511

# %%
plt.close()
#ggr = sea.load_dataset('oi')
fig, ax = plt.subplots()
ax.set_title('PIB Total')
fig.set_size_inches(25.7, 8.27)

sea.set_context("talk")

sea.set_color_codes("pastel")
sea.barplot(x="Valor", y="Presidente", data=pib_total)



#ax.legend(ncol=2, loc="upper left", frameon=True)
ax.set(ylabel= "Ano",
       xlabel="PIB Produzido Durante Mandato")
sea.despine(left=True, bottom=True)
sea.set_style("whitegrid")

# %% [markdown]
# ## Total de Investimentos (NID_NGDP)

# %%
nid = pd.read_csv('/home/joao/Projetos/trabalho_fasam/data_viz/data/geral/nid_ngdp.csv')



nid = nid.rename(index = str, columns={"Year": "Ano", "Value":"Valor(Porcentagem do PIB)"})

nid['Periodos'] = nid.apply(lambda row: periods(row), axis = 1)


nid['Ano'] = nid['Ano'].apply(lambda x: x[0:4])

nid = nid.apply(pd.to_numeric, errors = 'ignore')


nid
# Out:
#      Ano  Valor(Porcentagem do PIB) Periodos
# 0   1995                     19.850      FHC
# 1   1996                     17.564      FHC
# 2   1997                     18.052      FHC
# 3   1998                     18.463      FHC
# 4   1999                     17.735      FHC
# 5   2000                     19.119      FHC
# 6   2001                     18.870      FHC
# 7   2002                     17.552      FHC
# 8   2003                     17.057     Lula
# 9   2004                     18.039     Lula
# 10  2005                     17.437     Lula
# 11  2006                     18.044     Lula
# 12  2007                     19.991     Lula
# 13  2008                     21.800     Lula
# 14  2009                     18.956     Lula
# 15  2010                     21.796     Lula
# 16  2011                     21.808    Dilma
# 17  2012                     20.343    Dilma
# 18  2013                     21.001    Dilma
# 19  2014                     20.043    Dilma
# 20  2015                     19.006    Dilma
# 21  2016                     19.206    Dilma

# %%
plt.close()
fig2, ax2 = plt.subplots()
ax2.set_title('Total de Investimentos')
sea.set_context("talk")
fig2.set_size_inches(25.7, 8.27)
plt.axvline(x=1995, color='B', label='Início Governo FHC (1995)')
plt.axvline(x=2003, color=sea.xkcd_rgb["dusty purple"], label='Início Governo Lula (2003)')
plt.axvline(x=2011, color= sea.xkcd_rgb["pale red"], label = 'Início Governo Dilma (2011)')
sea.lineplot(x='Ano', y ='Valor(Porcentagem do PIB)', markers=True, data = nid)
sea.despine()
sea.set_style("whitegrid", {'axes.grid' : False})

# %%
oi = nid.groupby(nid['Periodos'], axis =0).sum()

oi.reset_index(level=0, inplace=True)

oi
# Out:
#   Periodos    Ano  Valor(Porcentagem do PIB)
# 0    Dilma  12081                    121.407
# 1      FHC  15988                    147.205
# 2     Lula  16052                    153.120

# %%
investimento = nid['Valor(Porcentagem do PIB)'].apply(lambda x: x/100)

tst = pib['Valor(Bilhões de Reais)'] * investimento

nid['Total Investido'] = tst

nid['PIB Total'] = pib['Valor(Bilhões de Reais)']

nid
# Out:
#      Ano  Valor(Porcentagem do PIB) Periodos  Total Investido  PIB Total
# 0   1995                     19.850      FHC       143.115522    720.985
# 1   1996                     17.564      FHC       150.674003    857.857
# 2   1997                     18.052      FHC       172.480361    955.464
# 3   1998                     18.463      FHC       185.735011   1005.985
# 4   1999                     17.735      FHC       193.715326   1092.277
# 5   2000                     19.119      FHC       229.882459   1202.377
# 6   2001                     18.870      FHC       248.389395   1316.319
# 7   2002                     17.552      FHC       261.732440   1491.183
# 8   2003                     17.057     Lula       293.392169   1720.069
# 9   2004                     18.039     Lula       353.330795   1958.705
# 10  2005                     17.437     Lula       378.685606   2171.736
# 11  2006                     18.044     Lula       434.824673   2409.802
# 12  2007                     19.991     Lula       543.361577   2718.031
# 13  2008                     21.800     Lula       677.441540   3107.530
# 14  2009                     18.956     Lula       630.888663   3328.174
# 15  2010                     21.796     Lula       847.174557   3886.835
# 16  2011                     21.808    Dilma       954.048751   4374.765
# 17  2012                     20.343    Dilma       958.784916   4713.095
# 18  2013                     21.001    Dilma      1083.141066   5157.569
# 19  2014                     20.043    Dilma      1106.625340   5521.256
# 20  2015                     19.006    Dilma      1131.732226   5954.605
# 21  2016                     19.206    Dilma      1221.170489   6358.276

# %%
plt.close()
#ggr = sea.load_dataset('oi')
fig, ax = plt.subplots()
ax.set_title('PIB Total x PIB Investido')
fig.set_size_inches(25.7, 8.27)

sea.set_context("talk")

sea.set_color_codes("pastel")
sea.barplot(x="Ano", y="PIB Total", label="PIB Total", color="b", data=nid)

sea.set_color_codes("pastel")
sea.barplot(x="Ano", y="Total Investido", data=nid, label="PIB Investido", color="y")


ax.legend(ncol=2, loc="upper left", frameon=True)
ax.set(ylabel= "Total Investido (Bilhões de Reais)",
       xlabel="")
sea.despine(left=True, bottom=True)
sea.set_style("whitegrid")

# %% [markdown]
# ## Inflação PCPI

# %%
pcpi = pd.read_csv('/home/joao/Projetos/trabalho_fasam/data_viz/data/geral/pcpi.csv')



pcpi = pcpi.rename(index = str, columns={"Year": "Ano", "Value":"Valor(Index)"})

pcpi['Periodos'] = pcpi.apply(lambda row: periods(row), axis = 1)


pcpi['Ano'] = pcpi['Ano'].apply(lambda x: x[0:4])

pcpi = pcpi.apply(pd.to_numeric, errors = 'ignore')


pcpi
# Out:
#      Ano  Valor(Index) Periodos
# 0   1995  7.519306e+12      FHC
# 1   1996  8.704156e+12      FHC
# 2   1997  9.306985e+12      FHC
# 3   1998  9.604458e+12      FHC
# 4   1999  1.007109e+13      FHC
# 5   2000  1.078049e+13      FHC
# 6   2001  1.151793e+13      FHC
# 7   2002  1.249119e+13      FHC
# 8   2003  1.432920e+13     Lula
# 9   2004  1.527464e+13     Lula
# 10  2005  1.632404e+13     Lula
# 11  2006  1.700699e+13     Lula
# 12  2007  1.762627e+13     Lula
# 13  2008  1.862714e+13     Lula
# 14  2009  1.953766e+13     Lula
# 15  2010  2.052217e+13     Lula
# 16  2011  2.188410e+13    Dilma
# 17  2012  2.306663e+13    Dilma
# 18  2013  2.449774e+13    Dilma
# 19  2014  2.604824e+13    Dilma
# 20  2015  2.809012e+13    Dilma
# 21  2016  2.974700e+13    Dilma

# %%
plt.close()
#ggr = sea.load_dataset('oi')
fig, ax = plt.subplots()
ax.set_title('Inflação Anual')
fig.set_size_inches(25.7, 8.27)

sea.set_context("talk")

sea.set_color_codes("pastel")
sea.barplot(x="Ano", y="Valor(Index)", hue='Periodos', data=pcpi)



ax.set(ylabel="Index",
       xlabel="Ano")
sea.despine(left=True, bottom=True)
sea.set_style("whitegrid")
